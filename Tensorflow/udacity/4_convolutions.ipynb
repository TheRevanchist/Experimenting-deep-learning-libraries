# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 3
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.AdamOptimizer(3e-4).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.724546
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.165663
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 2.189538
# Minibatch accuracy: 25.0%
# Validation accuracy: 27.3%
# Minibatch loss at step 150: 2.103970
# Minibatch accuracy: 25.0%
# Validation accuracy: 35.1%
# Minibatch loss at step 200: 1.717444
# Minibatch accuracy: 56.2%
# Validation accuracy: 57.1%
# Minibatch loss at step 250: 1.297319
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.0%
# Minibatch loss at step 300: 0.883803
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.0%
# Minibatch loss at step 350: 1.678527
# Minibatch accuracy: 43.8%
# Validation accuracy: 74.0%
# Minibatch loss at step 400: 0.745823
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.3%
# Minibatch loss at step 450: 1.309261
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.2%
# Minibatch loss at step 500: 0.828893
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 550: 0.855283
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 600: 0.451003
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 650: 0.620643
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 700: 0.434408
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 750: 1.456054
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 800: 0.962292
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 850: 2.036305
# Minibatch accuracy: 56.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 900: 0.856572
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.4%
# Minibatch loss at step 950: 0.815987
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 1000: 0.995102
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.9%
# Test accuracy: 87.9%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 3
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.AdamOptimizer(3e-4).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.966740
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.1%
# Minibatch loss at step 50: 2.245816
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.1%
# Minibatch loss at step 100: 2.387608
# Minibatch accuracy: 6.2%
# Validation accuracy: 17.8%
# Minibatch loss at step 150: 2.250359
# Minibatch accuracy: 12.5%
# Validation accuracy: 24.4%
# Minibatch loss at step 200: 2.046533
# Minibatch accuracy: 31.2%
# Validation accuracy: 37.4%
# Minibatch loss at step 250: 1.794112
# Minibatch accuracy: 62.5%
# Validation accuracy: 47.8%
# Minibatch loss at step 300: 1.178644
# Minibatch accuracy: 75.0%
# Validation accuracy: 61.2%
# Minibatch loss at step 350: 1.635999
# Minibatch accuracy: 43.8%
# Validation accuracy: 64.0%
# Minibatch loss at step 400: 0.906192
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.5%
# Minibatch loss at step 450: 1.282519
# Minibatch accuracy: 56.2%
# Validation accuracy: 73.4%
# Minibatch loss at step 500: 1.076237
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.7%
# Minibatch loss at step 550: 0.953779
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 600: 0.604212
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.2%
# Minibatch loss at step 650: 0.643318
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.4%
# Minibatch loss at step 700: 0.510428
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.4%
# Minibatch loss at step 750: 1.355151
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 800: 1.044454
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 850: 2.143729
# Minibatch accuracy: 56.2%
# Validation accuracy: 79.0%
# Minibatch loss at step 900: 1.108335
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 950: 1.273243
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 1000: 0.925329
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.9%
# Test accuracy: 85.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 128
patch_size = 3
depth_1 = 16
depth_2 = 32
num_hidden = 1024

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth_1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth_1]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth_1, depth_2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth_2]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth_2, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    data = tf.contrib.layers.batch_norm(data)    
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    data = tf.contrib.layers.batch_norm(pool)
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    data = tf.contrib.layers.batch_norm(pool)
    reshape = tf.reshape(data, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    data = tf.contrib.layers.batch_norm(hidden)
    return tf.matmul(data, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.AdamOptimizer(3e-4).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 7813 # 5 epochs

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.466269
# Minibatch accuracy: 10.9%
# Validation accuracy: 25.4%
# Minibatch loss at step 50: 0.888037
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.0%
# Minibatch loss at step 100: 0.926845
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.8%
# Minibatch loss at step 150: 0.512537
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.3%
# Minibatch loss at step 200: 0.523540
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 250: 0.557681
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.9%
# Minibatch loss at step 300: 0.373126
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.6%
# Minibatch loss at step 350: 0.524598
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.7%
# Minibatch loss at step 400: 0.459013
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 450: 0.475369
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.8%
# Minibatch loss at step 500: 0.561830
# Minibatch accuracy: 78.9%
# Validation accuracy: 86.7%
# Minibatch loss at step 550: 0.395022
# Minibatch accuracy: 88.3%
# Validation accuracy: 86.9%
# Minibatch loss at step 600: 0.463500
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.3%
# Minibatch loss at step 650: 0.460291
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.2%
# Minibatch loss at step 700: 0.493393
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 750: 0.584641
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.7%
# Minibatch loss at step 800: 0.339310
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.0%
# Minibatch loss at step 850: 0.458991
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.8%
# Minibatch loss at step 900: 0.420032
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 950: 0.463769
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 1000: 0.461294
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 1050: 0.353402
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.8%
# Minibatch loss at step 1100: 0.312990
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 1150: 0.426597
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.4%
# Minibatch loss at step 1200: 0.553193
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.4%
# Minibatch loss at step 1250: 0.275771
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 1300: 0.244690
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.8%
# Minibatch loss at step 1350: 0.235350
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 1400: 0.343862
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 1450: 0.501069
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.7%
# Minibatch loss at step 1500: 0.419503
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 1550: 0.300181
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.0%
# Minibatch loss at step 1600: 0.361737
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 1650: 0.391565
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 1700: 0.299637
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.8%
# Minibatch loss at step 1750: 0.268456
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 1800: 0.368704
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 1850: 0.313295
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 1900: 0.376107
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.1%
# Minibatch loss at step 1950: 0.373773
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 2000: 0.354172
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 2050: 0.354532
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 2100: 0.244226
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 2150: 0.367404
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.4%
# Minibatch loss at step 2200: 0.352393
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.4%
# Minibatch loss at step 2250: 0.481605
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.7%
# Minibatch loss at step 2300: 0.407593
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.6%
# Minibatch loss at step 2350: 0.293748
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# Minibatch loss at step 2400: 0.416748
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 2450: 0.325550
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 2500: 0.274482
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 2550: 0.329846
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 2600: 0.258945
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 2650: 0.443473
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 2700: 0.350254
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.1%
# Minibatch loss at step 2750: 0.295680
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.0%
# Minibatch loss at step 2800: 0.316694
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 2850: 0.275168
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 2900: 0.430525
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 2950: 0.143848
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 3000: 0.440001
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 3050: 0.178066
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 3100: 0.230287
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 3150: 0.412590
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.2%
# Minibatch loss at step 3200: 0.448435
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 3250: 0.258332
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 3300: 0.437190
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 3350: 0.172228
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.3%
# Minibatch loss at step 3400: 0.234785
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 3450: 0.334631
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 3500: 0.129863
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 3550: 0.291246
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 3600: 0.172632
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 3650: 0.332899
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 3700: 0.500367
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 3750: 0.233848
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 3800: 0.360253
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.4%
# Minibatch loss at step 3850: 0.241607
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 3900: 0.267888
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 3950: 0.312562
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
# Minibatch loss at step 4000: 0.339787
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 4050: 0.324673
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 4100: 0.163811
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 4150: 0.231830
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 4200: 0.214342
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 4250: 0.225391
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.7%
# Minibatch loss at step 4300: 0.299799
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.7%
# Minibatch loss at step 4350: 0.132408
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.7%
# Minibatch loss at step 4400: 0.278155
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 4450: 0.239975
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 4500: 0.299107
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 4550: 0.180869
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 4600: 0.322637
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 4650: 0.239243
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 4700: 0.233314
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.5%
# Minibatch loss at step 4750: 0.139742
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.6%
# Minibatch loss at step 4800: 0.297273
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 4850: 0.127311
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 4900: 0.200881
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 4950: 0.243504
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 5000: 0.279823
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# Minibatch loss at step 5050: 0.296123
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.6%
# Minibatch loss at step 5100: 0.180469
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.7%
# Minibatch loss at step 5150: 0.252974
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 5200: 0.158293
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.0%
# Minibatch loss at step 5250: 0.392452
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 5300: 0.271884
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 5350: 0.137110
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.7%
# Minibatch loss at step 5400: 0.257327
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.9%
# Minibatch loss at step 5450: 0.207526
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 5500: 0.166390
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 5550: 0.313803
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# Minibatch loss at step 5600: 0.245133
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 5650: 0.256558
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 5700: 0.154365
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.9%
# Minibatch loss at step 5750: 0.160893
# Minibatch accuracy: 97.7%
# Validation accuracy: 90.8%
# Minibatch loss at step 5800: 0.228742
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 5850: 0.280305
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.0%
# Minibatch loss at step 5900: 0.200684
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 5950: 0.226683
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 6000: 0.244032
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 6050: 0.274283
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.0%
# Minibatch loss at step 6100: 0.170905
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
# Minibatch loss at step 6150: 0.295775
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 6200: 0.218776
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.9%
# Minibatch loss at step 6250: 0.209639
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.0%
# Minibatch loss at step 6300: 0.208776
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 6350: 0.186699
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 6400: 0.181776
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
# Minibatch loss at step 6450: 0.142057
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.1%
# Minibatch loss at step 6500: 0.211292
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.3%
# Minibatch loss at step 6550: 0.152717
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.1%
# Minibatch loss at step 6600: 0.166676
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 6650: 0.245380
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 6700: 0.110369
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.1%
# Minibatch loss at step 6750: 0.198643
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 6800: 0.163350
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.7%
# Minibatch loss at step 6850: 0.156272
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 6900: 0.209728
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 6950: 0.174855
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
# Minibatch loss at step 7000: 0.150834
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 7050: 0.173643
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.7%
# Minibatch loss at step 7100: 0.277515
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.7%
# Minibatch loss at step 7150: 0.168867
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.9%
# Minibatch loss at step 7200: 0.204099
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 7250: 0.149723
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.0%
# Minibatch loss at step 7300: 0.142623
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.7%
# Minibatch loss at step 7350: 0.219712
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.1%
# Minibatch loss at step 7400: 0.365803
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 7450: 0.192251
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
# Minibatch loss at step 7500: 0.157173
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 7550: 0.180205
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
# Minibatch loss at step 7600: 0.193833
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 7650: 0.199740
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.1%
# Minibatch loss at step 7700: 0.334765
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.2%
# Minibatch loss at step 7750: 0.201691
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 7800: 0.156574
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
# Test accuracy: 96.2%
